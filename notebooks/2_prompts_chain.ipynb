# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=1.0,
    max_retries=0,
)

# %%
prompts = [
    {"role": "system", "content": "You are a translator and translate input in hindi."},
    {"role": "user", "content": "I love to play cricket."}
]
res = llm.invoke(prompts)

# %%
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है। (Mujhe cricket khelna bahut pasand hai.)

# %% [markdown]
# ### Dynamic Promts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=1.0,
    max_retries=0,
)
out = StrOutputParser()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role": "system", "content": "You are a translator and translate input in {language}."},
    {"role": "user", "content": "{query}"},
])
final_prompts = prompts.format_messages(language="hindi", query="I love to play cricket.")
res = llm.invoke(final_prompts)
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है। (Mujhe cricket khelna bahut pasand hai.)

# %%
bim = prompts.invoke({"language": "hindi", "query": "I love to play cricket."})
res = llm.invoke(bim)

# %%
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है।

# %%
def tranfrom_case(result : str):
    return result.upper()

# %%
chains = prompts | llm | out | tranfrom_case

# %%
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are a translator and translate input in {language}.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# | ChatGoogleGenerativeAI(model='models/gemini-3-flash-preview', google_api_key=SecretStr('**********'), temperature=1.0, max_retries=0, client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x11715a880>, default_metadata=(), model_kwargs={})
# | StrOutputParser()
# | RunnableLambda(tranfrom_case)

# %%
res = chains.invoke({"language": "hinglish", "query": "I love to you."})
print(res)
# Out:
# IN HINGLISH, YOU CAN SAY:
#
# **"MAIN TUMSE LOVE KARTA HOON"** (IF YOU ARE MALE)
# OR
# **"MAIN TUMSE LOVE KARTI HOON"** (IF YOU ARE FEMALE)
#
# ANOTHER COMMON WAY IS:
# **"MUJHE TUMSE PYAAR HAI."**
