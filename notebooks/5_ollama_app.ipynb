# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("Hello there!")
print(res.content)
# Out:
# Hi there! How's it going? Do you want to chat about something in particular? 😄
