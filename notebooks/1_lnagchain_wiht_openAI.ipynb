# %% [markdown]
# ### Load Env Variables

# %%
### LangChain Model - OpenAI
### DOTENV
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### connect with google gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-3.7-flash",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
res = llm.invoke("What is genAI?")

# %%
res.content
# Out:
# '**GenAI** (short for **Generative Artificial Intelligence**) is a type of artificial intelligence that can **create new, original content** rather than just analyzing or acting on existing data. \n\nInstead of just recognizing things (like identifying a cat in a photo), GenAI can generate entirely new text, images, music, code, or video based on simple written instructions called **"prompts."**\n\n---\n\n### How GenAI Differs from Traditional AI\n\n* **Traditional (Discriminative) AI:** Focuses on analyzing data and making decisions. \n  * *Example:* Recommending a movie on Netflix, recognizing your face to unlock your phone, or filtering spam emails.\n* **Generative AI:** Focuses on creation.\n  * *Example:* Writing a movie script from scratch, drawing a completely new face that doesn\'t exist, or writing an email for you.\n\n---\n\n### What Can GenAI Create?\n\n1. **Text (via Large Language Models / LLMs):** \n   * Writes essays, summarizes documents, translates languages, and answers questions.\n   * *Examples:* ChatGPT, Claude, Google Gemini.\n2. **Images:** \n   * Creates photorealistic scenes, digital art, or logos based on descriptions.\n   * *Examples:* Midjourney, DALL-E, Stable Diffusion.\n3. **Computer Code:** \n   * Writes, debugs, and explains code in languages like Python, JavaScript, and C++.\n   * *Examples:* GitHub Copilot, Cursor.\n4. **Audio and Music:** \n   * Clones voices, creates realistic voiceovers, or generates full musical tracks.\n   * *Examples:* Suno, ElevenLabs.\n5. **Video:** \n   * Generates realistic video clips from text descriptions.\n   * *Examples:* OpenAI Sora, Runway Gen-2.\n\n---\n\n### How Does It Work?\n\nGenAI uses advanced algorithms called **neural networks** (specifically modern architectures like *Transformers* and *Diffusion models*). \n\n1. **Training:** The AI is fed massive amounts of data (billions of web pages, books, images, or audio clips).\n2. **Pattern Recognition:** It learns the underlying patterns, structures, grammar, and rules of that data.\n3. **Generation (Prediction):** When you give it a prompt, it doesn\'t "copy and paste." Instead, it uses statistical probability to predict what should come next—word by word or pixel by pixel—to create something new that makes sense.\n\n---\n\n### Key Challenges of GenAI\n\n* **"Hallucinations":** GenAI can sometimes state false information with total confidence because it generates what *sounds* right, not necessarily what is true.\n* **Copyright & Ethics:** Models are trained on human-created art and writing, leading to debates over intellectual property and fair use.\n* **Deepfakes & Misinformation:** The ability to generate realistic fake images, audio, and video makes it easier to spread false information.'

# %% [markdown]
# ### Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-3.7-flash",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
prompts = [
    ("system", "You are a Java developer."), ### type system, ai, user
    ("user", "How to sort the array?")
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# In Java, the standard and most efficient way to sort an array is using the **`java.util.Arrays.sort()`** method.
#
# Here are the different ways to sort an array depending on your use case:
#
# ---
#
# ### 1. Sorting Primitive Arrays (Ascending Order)
# Works for `int[]`, `double[]`, `char[]`, etc. Uses Dual-Pivot Quicksort ($O(n \log n)$).
#
# ```java
# import java.util.Arrays;
#
# public class Main {
#     public static void main(String[] args) {
#         int[] numbers = { 5, 2, 8, 1, 9, 3 };
#
#         // Sort the array in ascending order
#         Arrays.sort(numbers);
#
#         System.out.println(Arrays.toString(numbers));
#         // Output: [1, 2, 3, 5, 8, 9]
#     }
# }
# ```
#
# ---
#
# ### 2. Sorting in Descending Order
# To sort in reverse order, you must use **Wrapper objects** (e.g., `Integer[]` instead of `int[]`) and `Collections.reverseOrder()`.
#
# ```java
# import java.util.Arrays;
# import java.util.Collections;
#
# public class Main {
#     public static void main(String[] args) {
#         Integer[] numbers = { 5, 2, 8, 1, 9, 3 };
#
#         // Sort in descending order
#         Arrays.sort(numbers, Collections.reverseOrder());
#
#         System.out.println(Arrays.toString(numbers));
#         // Output: [9, 8, 5, 3, 2, 1]
#     }
# }
# ```
#
# ---
#
# ### 3. Sorting Strings (Alphabetical Order)
# Strings are sorted lexicographically (case-sensitive by default).
#
# ```java
# import java.util.Arrays;
#
# public class Main {
#     public static void main(String[] args) {
#         String[] fruits = { "Banana", "Apple", "Mango", "Cherry" };
#
#         Arrays.sort(fruits);
#
#         System.out.println(Arrays.toString(fruits));
#         // Output: [Apple, Banana, Cherry, Mango]
#     }
# }
# ```
#
# ---
#
# ### 4. Sorting Custom Objects (Using `Comparator`)
# For custom classes, you can use modern Java Lambdas or `Comparator.comparing()`.
#
# ```java
# import java.util.Arrays;
# import java.util.Comparator;
#
# class Employee {
#     String name;
#     int age;
#
#     Employee(String name, int age) {
#         this.name = name;
#         this.age = age;
#     }
#
#     @Override
#     public String toString() {
#         return name + " (" + age + ")";
#     }
# }
#
# public class Main {
#     public static void main(String[] args) {
#         Employee[] employees = {
#             new Employee("John", 28),
#             new Employee("Alice", 22),
#             new Employee("Bob", 35)
#         };
#
#         // Sort by age (Ascending)
#         Arrays.sort(employees, Comparator.comparingInt(emp -> emp.age));
#
#         System.out.println(Arrays.toString(employees));
#         // Output: [Alice (22), John (28), Bob (35)]
#     }
# }
# ```
#
# ---
#
# ### 5. Sorting a Subarray (Partial Sort)
# You can sort only a specific range inside the array using start and end indices: `Arrays.sort(array, fromIndex, toIndex)`.
#
# ```java
# int[] numbers = { 9, 8, 7, 6, 5, 4, 3, 2, 1 };
#
# // Sort elements from index 2 to index 6 (exclusive)
# Arrays.sort(numbers, 2, 6);
#
# System.out.println(Arrays.toString(numbers));
# // Output: [9, 8, 5, 6, 7, 4, 3, 2, 1]
# ```
#
# ---
#
# ### 💡 Performance Tip for Large Arrays
# If you are dealing with very large arrays (e.g., millions of elements), use **`Arrays.parallelSort()`**. It utilizes multiple CPU cores (via the Fork/Join framework) to sort much faster.
#
# ```java
# Arrays.parallelSort(largeArray);
# ```
