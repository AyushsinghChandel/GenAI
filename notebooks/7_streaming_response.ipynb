# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash" , streaming=True)

# %%
res = llm.stream("Can you explain me GenAI?")

# %%
for chunk in res:
    print(chunk.content, end="")
# Out:
# [{'type': 'text', 'text': 'At its simplest, **Generative AI (GenAI)** is a type of artificial intelligence that can **create brand', 'index': 0}][{'type': 'text', 'text': '-new content**. \n\nUnlike traditional AI, which is designed to analyze existing data or follow strict rules, GenAI acts', 'index': 0}][{'type': 'text', 'text': ' like a digital creator. Give it a prompt (an instruction in plain human language), and it can generate **text, images, music', 'index': 0}][{'type': 'text', 'text': ', code, or videos** that have never existed before.\n\nHere is a simple guide to understanding GenAI.\n\n', 'index': 0}][{'type': 'text', 'text': '---\n\n### 1. Traditional AI vs. Generative AI\nTo understand GenAI, it helps to compare it to the', 'index': 0}][{'type': 'text', 'text': ' AI we’ve used for years:\n\n*   **Traditional AI (Analyzer):** Looks at a photo of a dog', 'index': 0}][{'type': 'text', 'text': ' and says, *"This is a dog with 99% accuracy."* It organizes, classifies, or pr
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm_groq = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
res = llm.stream("Can you explain me GenAI?")

# %%
for chunk in res:
    print(chunk.content, end="")
# Out:
# [{'type': 'text', 'text': '**Generative AI (GenAI)** is a branch of Artificial Intelligence focused on **creating new content** rather', 'index': 0}][{'type': 'text', 'text': ' than just analyzing existing data. \n\nWhile traditional AI is built to evaluate, classify, or predict things (like deciding', 'index': 0}][{'type': 'text', 'text': ' if an email is spam), **GenAI creates entirely new things**—like text, images, music, code, or', 'index': 0}][{'type': 'text', 'text': ' videos—that look like they were made by a human.\n\nHere is a simple breakdown of how it works, what it can', 'index': 0}][{'type': 'text', 'text': ' do, and why it matters.\n\n---\n\n### 1. Traditional AI vs. Generative AI\n\nTo understand Gen', 'index': 0}][{'type': 'text', 'text': 'AI, it helps to contrast it with traditional AI:\n\n*   **Traditional AI (Analyzer):** You show it', 'index': 0}][{'type': 'text', 'text': ' 10,000 photos of cats, and it learns to answer: *"Is there a cat in this picture?"', 'inde
# ...
